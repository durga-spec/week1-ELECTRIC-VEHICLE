# %%
import pandas as pd
df=pd.read_csv("EVDATASET.csv")
df.head()
# Out:
#    Year  Country    Brand          Model  Battery_kWh  Range_km  \
# 0  2016    China     Tata       Nexon EV         69.9       332
# 1  2018      USA  Hyundai  Kona Electric         50.6       353
# 2  2022    India     Tata       Nexon EV         39.7       381
# 3  2019  Germany    Tesla        Model S         49.1       268
# 4  2024  Germany     Audi         e-tron         59.7       490
#
#    Motor_Power_kW  Weight_kg  Price_USD  Charging_Stations  Sales  \
# 0             135       1789      33741              50789   1520
# 1             117       1509      36758              36337   1478
# 2              88       1387      26752               3473   1832
# 3             101       1367      65866              33699   1018
# 4              87       1793      54986              48335   3072
#
#    Govt_Incentive_USD
# 0                1200
# 1                 900
# 2                 600
# 3                 810
# 4                 360

# %% [markdown]
# ### ELECTRIC VEHICLE DATASET ANALYSIS
# ### OBJECTIVE
# To perform initial data loading and exploration on an electric vehicle dataset using python and pandas
# ### STEPS PERFORMED
# 1. imported the pandas library
# 2. loaded the dataset(EVDATASET.csv)using pd.read_csv()
# 3. displayed the first few rows with df.read() to verify successful loading
# ### OBSERVATION
# 1. the dataset contains details like year , country,brand,model,battery(kwh),range(km),motor power,weight,price,charging stations,and sales.
#    data appeared clean for further analysis
